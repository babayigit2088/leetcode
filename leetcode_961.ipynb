# %%
import urllib.request
from bs4 import BeautifulSoup as soup
import csv
my_url="018-12-03&checkout=2018-12-04&adults=1&children=0&infants=0&guests=0&place_id=ChIJ5S-raZElv0cR8HcqSvxgJwQ&refinement_paths%5B%5D=%2Fhomes&allow_override%5B%5D=&s_tag=Qb37EmWs"
page = urllib.request.urlopen(my_url)
soup=BeautifulSoup(page,"html.parser")

print(soup)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-4aaef813c2ce> in <module>()
#       3 import csv
#       4 my_url="https://www.airbnb.de/s/K%C3%B6ln/homes?query=K%C3%B6ln&checkin=2018-12-03&checkout=2018-12-04&adults=1&children=0&infants=0&guests=0&place_id=ChIJ5S-raZElv0cR8HcqSvxgJwQ&refinement_paths%5B%5D=%2Fhomes&allow_override%5B%5D=&s_tag=Qb37EmWs"
# ----> 5 page = urllib.request.urlopen(my_url)
#       6 soup=BeautifulSoup(page,"html.parser")
#       7
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
# ...

# %%
uClient=UReq(my_url)
page_html=uClient.read()
uClient.close()

page_soup=soup(page_html,"html.parser")

containers=page_soup.find_all("div", {"class": "item-container"})

for container in containers:
    
    title_container=container.find_all("a", {"class":"item-title"})
    product_name=title_container[0].text
    
    print(product_name)



import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup

list_id= []
price = []
date = []
area = []
owner = []
room = []
seller = []
adres = []
title = []

for j in range(0,290,18):
    
    r = requests.get("https://tr.airbnb.com/s/London--%C4%B0ngiltere/homes?refinement_paths%5B%5D=%2Fhomes&checkin=2018-11-29&checkout=2018-11-30&adults=1&children=0&infants=0&guests=1&toddlers=0&place_id=ChIJdd4hrwug2EcRmSrV3Vo6llI&query=London%2C%20%C4%B0ngiltere&allow_override%5B%5D=&s_tag=FP460i87&section_offset=7&items_offset={}".format(j))

    soup = BeautifulSoup(r.text,'html.parser')
    results = soup.find_all("div", attrs={'class':'_8ssblpx'})

    for tag in results :
        tip=soup.find_all("small",attrs={"class":"_13dbiegr"})
        price.append(tag.get('data-price'))
        date.append(tag.get('data-date'))
        area.append(tag.get('data-meter'))
        owner.append(tag.get('data-owner'))
        room.append(tag.get('data-room'))
        seller.append(tag.get('data-seller-type'))
        adres.append(tag.get('href'))
        title.append(tag.get('title'))
        list_id.append(tag.get('data-listing-id'))

records={"list_id":list_id,"title": title, "price": price, "date":date, "area-m2": area, "owner":owner, "room": room, "seller": seller, "adres":adres, }
 
#w = csv.writer(open("hurriyet.csv", "w"))

#for key, val in records.items():

        #w.writerow([key, val])
df = pd.DataFrame(records)
 
df.to_csv("{}hurriyet.txt".format(j))

# %%
for i in range(0,290,18):
    print(i)
# Out:
# 0
# 18
# 36
# 54
# 72
# 90
# 108
# 126
# 144
# 162
# 180
# 198
# 216
# 234
# 252
# 270
# 288

# %%
import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
#tip_list = []
#for j in range(0,37,18):
#source.find("a",attrs={"class":"item_1523a"}).text    
r = requests.get("https://www.airbnb.de/s/K%C3%B6ln/homes?query=K%C3%B6ln&checkin=2018-12-03&checkout=2018-12-04&adults=1&children=0&infants=0&guests=0&place_id=ChIJ5S-raZElv0cR8HcqSvxgJwQ&refinement_paths%5B%5D=%2Fhomes&allow_override%5B%5D=&s_tag=Qb37EmWs")
print(r)
source = BeautifulSoup(r.content,"lxml")
soup =source.find("a",attrs={"class":"_1ol0z3h"})
#results = soup.find_all("div", attrs={'class':'_8ssblpx'})
#print(results)
    #for tag in results :
       # tip=soup.find_all("div",attrs={"class":"_1etkxf1"})
        #tip_list.append(tip)
#print(tip_list)
print(soup)
# Out:
#   File "<ipython-input-13-2003ac9c0bc9>", line 11
#     soup =source.find("a",attrs={"class":"_1ol0z3h"},text)
#                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup

list_id= []
price = []
date = []
area = []
owner = []
room = []
seller = []
adres = []
title = []

for j in range():
    
    r = requests.get("https://www.ebay-kleinanzeigen.de/s-wohnung-mieten/koeln/seite:{}/wohnung/k0c203l945r30".format(j))

    soup = BeautifulSoup(r.text,'html.parser')
    results = soup.find_all("div", attrs={'class':'_8ssblpx'})

    for tag in results :
        tip=soup.find_all("small",attrs={"class":"_13dbiegr"})
        price.append(tag.get('data-price'))
        date.append(tag.get('data-date'))
        area.append(tag.get('data-meter'))
        owner.append(tag.get('data-owner'))
        room.append(tag.get('data-room'))
        seller.append(tag.get('data-seller-type'))
        adres.append(tag.get('href'))
        title.append(tag.get('title'))
        list_id.append(tag.get('data-listing-id'))

records={"list_id":list_id,"title": title, "price": price, "date":date, "area-m2": area, "owner":owner, "room": room, "seller": seller, "adres":adres, }
 
#w = csv.writer(open("hurriyet.csv", "w"))

#for key, val in records.items():

        #w.writerow([key, val])
df = pd.DataFrame(records)
 
df.to_csv("{}hurriyet.txt".format(j))

# %%
import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup


price = []
date = []
area = []
owner = []
room = []
seller = []
image_nu = []
title = []
floor = []

for j in range(1,26):
    
    r = requests.get("https://www.hurriyetemlak.com/konut-kiralik/istanbul-sahibinden/listeleme?pageSize=50&page={}".format(j))

    soup = BeautifulSoup(r.text,'html.parser')
    results = soup.find_all("a", attrs={'class':'overlay-link'})
   
    for tag in results :
        price.append(tag.get('data-price'))
        date.append(tag.get('data-date'))
        area.append(tag.get('data-meter'))
        owner.append(tag.get('data-owner'))
        room.append(tag.get('data-room'))
        seller.append(tag.get('data-seller-type'))
        image_nu.append(tag.get('data-img-count'))
        title.append(tag.get('title'))        
        floor.append(tag.get('data-floor'))
records={"floor":floor,"title": title, "price": price, "date":date, "area-m2": area, "owner":owner, "room": room, "seller": seller, "image_nu":image_nu }

#w = csv.writer(open("hurriyet.csv", "w"))

#for key, val in records.items():

        #w.writerow([key, val])
df1 = pd.DataFrame(records)
#df.to_csv("C:\\Users\\babay\\hurriyet_istanbul_rent.csv")

#df.to_csv("{}hurriyet.txt".format(j))

# %%
df1.head()
# Out:
#           floor                                              title  price  \
# 0        3. Kat                   Şişli Temiz Eşyalı Kiralık Daire  2.750
# 1  Yüksek Giriş                         Eşyalı Temiz Kiralık Daire  2.250
# 2        2. Kat  SAHİBİNDEN BAĞDAT CADDESİNE VE TREN İSTASYONUN...  3.250
# 3    En Üst Kat                                    Bay Ev Arkadaşı    450
# 4       13. Kat  SİTE İÇERİSİNDE SAHİBİNDEN KİRALIK LÜKS 1+1 DAİRE  1.300
#
#          date area-m2       owner room    seller image_nu
# 0  25.11.2018      85  Sahibinden  2+1  Bireysel       11
# 1  25.11.2018      60  Sahibinden  1+1  Bireysel       10
# 2  25.11.2018     180  Sahibinden  4+1  Bireysel        9
# 3  25.11.2018      90  Sahibinden  3+1  Bireysel        7
# 4  20.11.2018      70  Sahibinden  1+1  Bireysel       15

# %%
df1.shape
# Out:
# (2500, 9)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 9 columns):
# floor       1250 non-null object
# title       2500 non-null object
# price       1250 non-null object
# date        1250 non-null object
# area-m2     1250 non-null object
# owner       1250 non-null object
# room        1250 non-null object
# seller      2500 non-null object
# image_nu    1250 non-null object
# dtypes: object(9)
# memory usage: 175.9+ KB

# %%
df1
# Out:
#              floor                                              title  price  \
# 0           3. Kat                   Şişli Temiz Eşyalı Kiralık Daire  2.750
# 1     Yüksek Giriş                         Eşyalı Temiz Kiralık Daire  2.250
# 2           2. Kat  SAHİBİNDEN BAĞDAT CADDESİNE VE TREN İSTASYONUN...  3.250
# 3       En Üst Kat                                    Bay Ev Arkadaşı    450
# 4          13. Kat  SİTE İÇERİSİNDE SAHİBİNDEN KİRALIK LÜKS 1+1 DAİRE  1.300
# 5           3. Kat  EYÜP CAMİİNE  MESAFEDE,ÇARŞI YANIBAŞINDA,,DÜZA...  1.750
# 6           3. Kat  Sahibinden Büyükçekmece Kalecik Sitesinde 2+1 ...  1.000
# 7           7. Kat       SAHİBİNDEN KİRALIK 3 + 1   120 m2   1.650TL.  1.650
# 8          Ara Kat  Sahibinden Kiralık Sarıyer Büyükdere de 2+1 daire  2.000
# 9           1. Kat  EMLAKÇI,KOMİSYON YOK MAL SAHİBİNDEN, TAŞDELEND...  1.375
# 10          4. Kat  SAHİBİNDEN KİRALIK, METRO\u0027YA 50 M MESAFED...  2.000
# ...

# %%
import pandas as pd
import numpy as np
cols=["year", "population", "live_births", "deaths", "immigrations", "emigrations", "marriages", "divorces"]
df1=pd.read_excel("sweden_population _1.xlsx", names=cols, skiprows=2, parse_dates="year", error="coerce")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-61e890d7cabe> in <module>()
#       2 import numpy as np
#       3 cols=["year", "population", "live_births", "deaths", "immigrations", "emigrations", "marriages", "divorces"]
# ----> 4 df1=pd.read_excel("sweden_population _1.xlsx", names=cols, skiprows=2, parse_dates="year", error="coerce")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
a = [5,1,5,2]

a.count(5)
# Out:
# 2

# %%
a[0]
# Out:
# 5
